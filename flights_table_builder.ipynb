# %% [markdown]
# # Flights Table Builder
#
# By Kenneth Burchfiel
#
# Released under the MIT license
#
# This program converts various source files into a table from which airline route maps can be generated.
#
# I plan to add additional documentation at a later date.
#
# **Note**: The following files were not included in the GitHub repository because their size exceeds 100MB:
# 1. routes_planes_coordinates.csv
# 2. routes_planes_coordinates_for_mapping.csv
# 3. 21503323_T_T100_SEGMENT_ALL_CARRIER.csv
# 4. routes_planes_coordinates_for_mapping_v2.csv
#
# You can instead retrieve these files from my copy of this project on Google Drive, available at https://drive.google.com/drive/folders/1jRTjoZtT6OWCXRTNstG9D4CxmjXe4W8q?usp=sharing .

# %%
import pandas as pd
import cartopy.crs as ccrs # https://scitools.org.uk/cartopy/docs/latest/matplotlib/intro.html
import time
import matplotlib.pyplot as plt
import numpy as np

airport_list = pd.read_csv('original_data\\GlobalAirportDatabase.txt',
delimiter=':',names=['icao_code', 'iata_code', 'airport_name', 'city/town', 
'country', 'lat_deg', 'lat_min', 'lat_sec', 'lat_dir', 'lon_deg', 'lon_min', 
'lon_sec', 'lon_dir', 'altitude', 'latitude_dec_deg', 'longitude_dec_deg']) 
# Headers are not included in the CSV, so they are instead based on those in the
# dictionary here:
# https://www.partow.net/miscellaneous/airportdatabase/index.html . License:
# "Free use of The Global Airport Database is permitted under the guidelines and
# in accordance with the MIT License." (See
# https://www.partow.net/miscellaneous/airportdatabase/index.html#GlobalAirportDatabaseLicense
# )

airport_list
# Out:
#      icao_code iata_code airport_name    city/town           country  lat_deg  \
# 0         AYGA       GKA       GOROKA       GOROKA  PAPUA NEW GUINEA        6
# 1         AYLA       LAE          NaN          LAE  PAPUA NEW GUINEA        0
# 2         AYMD       MAG       MADANG       MADANG  PAPUA NEW GUINEA        5
# 3         AYMH       HGU  MOUNT HAGEN  MOUNT HAGEN  PAPUA NEW GUINEA        5
# 4         AYNZ       LAE       NADZAB       NADZAB  PAPUA NEW GUINEA        6
# ...        ...       ...          ...          ...               ...      ...
# 9295      ZYTK       NaN          NaN     SHENYANG             CHINA        0
# 9296      ZYTL       DLC   ZHOUSHUIZI       DALIAN             CHINA       38
# 9297      ZYXC       NaN          NaN    XIANCHENG             CHINA        0
# 9298      ZYYC       NaN          NaN       YICHUN             CHINA        0
# 9299      ZYYJ       NaN        YANJI        YANJI             CHINA       42
#
#       lat_min  lat_sec lat_dir  lon_deg  lon_min  lon_sec lon_dir  altitude  \
# 0           4       54       S      145       23       30       E      1610
# 1           0        0       U        0        0        0       U         0
# 2          12       25       S      145       47       19       E         7
# 3          49       34       S      144       17       46       E      1643
# 4          34       11       S      146       43       34       E        73
# ...       ...      ...     ...      ...      ...      ...     ...       ...
# 9295        0        0       U        0        0        0       U         0
# 9296       57       56       N      121       32       18       E        33
# 9297        0        0       U        0        0        0       U         0
# 9298        0        0       U        0        0        0       U         0
# 9299       52       54       N      129       26       54       E       191
#
#       latitude_dec_deg  longitude_dec_deg
# 0               -6.082            145.392
# 1                0.000              0.000
# 2               -5.207            145.789
# 3               -5.826            144.296
# 4               -6.570            146.726
# ...                ...                ...
# 9295             0.000              0.000
# 9296            38.966            121.538
# 9297             0.000              0.000
# 9298             0.000              0.000
# 9299            42.882            129.448
#
# [9300 rows x 16 columns]

# %%
origin_airport_list_for_merge = airport_list[['iata_code', 'latitude_dec_deg', 
'longitude_dec_deg']].copy()
origin_airport_list_for_merge.rename(columns={'iata_code': 'origin_iata_code',
'latitude_dec_deg':'origin_lat','longitude_dec_deg':'origin_lon'},inplace=True)
origin_airport_list_for_merge
# Out:
#      origin_iata_code  origin_lat  origin_lon
# 0                 GKA      -6.082     145.392
# 1                 LAE       0.000       0.000
# 2                 MAG      -5.207     145.789
# 3                 HGU      -5.826     144.296
# 4                 LAE      -6.570     146.726
# ...               ...         ...         ...
# 9295              NaN       0.000       0.000
# 9296              DLC      38.966     121.538
# 9297              NaN       0.000       0.000
# 9298              NaN       0.000       0.000
# 9299              NaN      42.882     129.448
#
# [9300 rows x 3 columns]

# %%
destination_airport_list_for_merge = airport_list[['iata_code', 
'latitude_dec_deg', 'longitude_dec_deg']].copy()
destination_airport_list_for_merge.rename(columns={'iata_code': 
'destination_iata_code','latitude_dec_deg':'destination_lat',
'longitude_dec_deg':'destination_lon'},inplace=True)
destination_airport_list_for_merge
# Out:
#      destination_iata_code  destination_lat  destination_lon
# 0                      GKA           -6.082          145.392
# 1                      LAE            0.000            0.000
# 2                      MAG           -5.207          145.789
# 3                      HGU           -5.826          144.296
# 4                      LAE           -6.570          146.726
# ...                    ...              ...              ...
# 9295                   NaN            0.000            0.000
# 9296                   DLC           38.966          121.538
# 9297                   NaN            0.000            0.000
# 9298                   NaN            0.000            0.000
# 9299                   NaN           42.882          129.448
#
# [9300 rows x 3 columns]

# %%
route_list = pd.read_csv(
    'original_data\\21503323_T_T100_SEGMENT_ALL_CARRIER.csv', 
    low_memory = False) # Source: Air Carriers : T-100 Segment (All Carriers);
    # 2018 'All months' data. Link:
    # https://www.transtats.bts.gov/DL_SelectFields.asp?gnoyr_VQ=FMG
route_list
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED    PAYLOAD   SEATS  \
# 0                        0.0                   1.0    21502.0    76.0
# 1                        0.0                   3.0    64506.0   228.0
# 2                        0.0                   1.0    21502.0    76.0
# 3                        0.0                   1.0    21502.0    76.0
# 4                        0.0                   1.0    12500.0    50.0
# ...                      ...                   ...        ...     ...
# 475214                1166.0                 583.0  1049400.0  5247.0
# 475215                1188.0                 594.0  1069200.0  5346.0
# 475216                1216.0                 608.0  1094400.0  5472.0
# 475217                1258.0                 629.0  1132200.0  5661.0
# 475218                2170.0                  44.0    74400.0   264.0
#
#         PASSENGERS  FREIGHT  MAIL  DISTANCE  RAMP_TO_RAMP  AIR_TIME  ...  \
# 0              3.0      0.0   0.0     901.0         170.0     140.0  ...
# 1             75.0      0.0   0.0     228.0         219.0     140.0  ...
# 2             64.0      0.0   0.0     851.0         144.0     114.0  ...
# 3             55.0      0.0   0.0     122.0          58.0      31.0  ...
# 4             34.0      0.0   0.0     133.0          49.0      29.0  ...
# ...            ...      ...   ...       ...           ...       ...  ...
# 475214      3646.0      0.0   0.0      91.0       27284.0   21338.0  ...
# 475215      3573.0      0.0   0.0      91.0       27799.0   21740.0  ...
# 475216      3827.0      0.0   0.0      91.0       28454.0   22253.0  ...
# 475217      4056.0      0.0   0.0      91.0       29437.0   23021.0  ...
# 475218         0.0      0.0  44.0      59.0        1860.0       0.0  ...
#
#        AIRCRAFT_GROUP  AIRCRAFT_TYPE AIRCRAFT_CONFIG  YEAR QUARTER MONTH  \
# 0                   6            638               1  2018       1     2
# 1                   6            638               1  2018       1     2
# 2                   6            638               1  2018       1     2
# 3                   6            638               1  2018       1     2
# 4                   6            629               1  2018       1     2
# ...               ...            ...             ...   ...     ...   ...
# 475214              1            125               1  2018       3     7
# 475215              1            125               1  2018       3     7
# 475216              1            125               1  2018       3     8
# 475217              1            125               1  2018       3     8
# 475218              3            340               1  2018       4    10
#
#        DISTANCE_GROUP  CLASS  DATA_SOURCE  Unnamed: 50
# 0                   2      F           DU          NaN
# 1                   1      F           DU          NaN
# 2                   2      F           DU          NaN
# 3                   1      F           DU          NaN
# 4                   1      F           DU          NaN
# ...               ...    ...          ...          ...
# 475214              1      F           DU          NaN
# 475215              1      F           DU          NaN
# 475216              1      F           DU          NaN
# 475217              1      F           DU          NaN
# 475218              1      F           DU          NaN
#
# [475219 rows x 51 columns]

# %%
route_list.columns
# Out:
# Index(['DEPARTURES_SCHEDULED', 'DEPARTURES_PERFORMED', 'PAYLOAD', 'SEATS',
#        'PASSENGERS', 'FREIGHT', 'MAIL', 'DISTANCE', 'RAMP_TO_RAMP', 'AIR_TIME',
#        'UNIQUE_CARRIER', 'AIRLINE_ID', 'UNIQUE_CARRIER_NAME',
#        'UNIQUE_CARRIER_ENTITY', 'REGION', 'CARRIER', 'CARRIER_NAME',
#        'CARRIER_GROUP', 'CARRIER_GROUP_NEW', 'ORIGIN_AIRPORT_ID',
#        'ORIGIN_AIRPORT_SEQ_ID', 'ORIGIN_CITY_MARKET_ID', 'ORIGIN',
#        'ORIGIN_CITY_NAME', 'ORIGIN_STATE_ABR', 'ORIGIN_STATE_FIPS',
#        'ORIGIN_STATE_NM', 'ORIGIN_COUNTRY', 'ORIGIN_COUNTRY_NAME',
#        'ORIGIN_WAC', 'DEST_AIRPORT_ID', 'DEST_AIRPORT_SEQ_ID',
#        'DEST_CITY_MARKET_ID', 'DEST', 'DEST_CITY_NAME', 'DEST_STATE_ABR',
#        'DEST_STATE_FIPS', 'DEST_STATE_NM', 'DEST_COUNTRY', 'DEST_COUNTRY_NAME',
#        'DEST_WAC', 'AIRCRAFT_GROUP', 'AIRCRAFT_TYPE', 'AIRCRAFT_CONFIG',
#        'YEAR', 'QUARTER', 'MONTH', 'DISTANCE_GROUP', 'CLASS', 'DATA_SOURCE',
#        'Unnamed: 50'],
#       dtype='object')

# %%
pd.unique(route_list['UNIQUE_CARRIER_NAME'])
# Out:
# array(['Endeavor Air Inc.', 'Ameristar Air Cargo',
#        'Trans States Airlines', 'Scott Air LLC dba Island Air Express',
#        'Alaska Central Express', 'Peninsula Airways Inc.',
#        'Caribbean Sun Airlines, Inc. d/b/a World Atlantic Airlines',
#        'Cavok Air LLC', 'Aerolitoral', 'Aeromexico',
#        'Eva Airways Corporation', 'China Cargo Airline',
#        'Nippon Cargo Airlines', 'Jin Air Co Ltd.',
#        'Grand Canyon Airlines, Inc. d/b/a Grand Canyon Airlines d/b/a Scenic Airlines',
#        'Menagerie Enterprises Inc d/b/a Monarch Air',
#        'Alaska Airlines Inc.', 'Hainan Airlines Company Limited',
#        'Oceanair Linhas Aereas S A', 'Cargologicair Limited',
#        'Ukraine International Airlines', 'Scandinavian Airlines Sys.',
#        'Brussels Airlines N.V.', 'Saudi Arabian Airlines Corp',
#        'TUI Airlines Belgium N.V. d/b/a Jetairfly', 'Air Tahiti Nui',
#        'Tap-Portuguese Airlines', 'Hong Kong Express Airways Limited',
#        'VistaJet Limited', 'Star Marianas Air Inc.', 'Gem Air LLC',
#        'Warbelow', 'American Airlines Inc.',
#        'Mokulele Flight Services, Inc.', 'Sky Lease Cargo',
#        'Condor Flugdienst', 'Emirates',
#        'Fast Colombia SAS d/b/a Viva Colombia', 'Air Serbia',
#        'Virgin Atlantic Airways',
#        'Compagnie Aerienne Inter Regionale Express dba Air Antilles Express & Air Guyane',
#        'Cargolux Airlines International S.A', 'Polskie Linie Lotnicze',
#        'Xiamen Airlines Co., Ltd.', 'Allegiant Air',
#        'GoJet Airlines LLC d/b/a United Express', 'Kenmore Air Harbor',
#        'Asia Pacific', 'Swiss Air Ambulance', 'Albinati Aeronautics SA',
#        'Qatar Airways (Q.C.S.C)', 'South African Airways',
#        'Aeroflot Russian Airlines', 'Turk Hava Yollari A.O.',
#        'WOW Air ehf', 'Air Georgian', 'Avjet Corporation',
#        'Via Airlines d/b/a Charter Air Transport', 'ABX Air Inc',
#        'Gulf And Caribbean Cargo', 'Kalitta Air LLC',
#        'Lynden Air Cargo Airlines',
#        'National Air Cargo Group Inc d/ba National Airlines',
#        'Mesa Airlines Inc.', 'PM Air, LLC',
#        'Corvus Airlines, Inc d/b/a Era Aviation d/b/a Ravn Alaska',
#        'Bering Air Inc.', 'Iliamna Air Taxi', 'Air Excursions LLC',
#        'Bidzy Ta Hot Aana, Inc. d/b/a Tanana Air Service',
#        'Southwest Airlines Co.', 'Cargojet Airways Ltd.', 'Lan Ecuador',
#        'Concesionaria Vuela Compania De Aviacion SA de CV (Volaris)',
#        'Yangtze River Express Airlines Company', 'Tradewind Aviation',
#        'Tropic Ocean Airways LLC', 'Island Air Service',
#        'Harris Air Services',
#        'CFM Inc d/b/a Contour Airlines d/b/a One Jet Shuttle',
#        'Polar Air Cargo Airways',
#        'Sun Country Airlines d/b/a MN Airlines', 'Republic Airline',
#        'Jazz Aviation LP',
#        'Tantalus Air Ltd. d/b/a Harbour Air d/b/a Harbour Air Seaplanes',
#        'Air Canada rouge LP', 'Singapore Airlines Ltd.',
#        'Taca International Airlines', 'Taca Peru',
#        'Scoot Tigerair Pte Ltd d/b/a Scoot',
#        'Virgin Blue International Airlines t/a V Australia',
#        'Aeroenlaces Nacionales, S.A. de C.V. d/b/a VivaAerobus',
#        'Sunwing Airlines Inc.', 'Westjet', 'Boutique Air',
#        'Air Transport International', 'Federal Express Corporation',
#        'Delta Air Lines Inc.', 'Envoy Air', 'China Airlines Ltd.',
#        'All Nippon Airways Co.', 'Air Japan Co', 'Porter Airlines, Inc.',
#        'SkyLink Express Inc.', 'Primera Air Scandinavia',
#        'Polynesian Airlines Ltd.', 'Qantas Airways Ltd.',
#        'AirBridgeCargo Airlines Limited', 'Sata Internacional',
#        'XL Airways France', 'Global Jet Luxembourg, Sa',
#        'Miami Air International',
#        'Paklook Air, Inc d/b/a/ Airlift Alaska d/b/a/ Yute Commuter Service',
#        'Aloha Air Cargo', 'Northern Air Cargo Inc.',
#        'ACM AIR CHARTER GmbH', 'Aerovias Nacl De Colombia', 'Lacsa',
#        'Maritime Helicopters, Inc.', 'Smokey Bay Air Inc.',
#        'Pacific Airways, Inc.',
#        'Tatonduk Outfitters Limited d/b/a Everts Air Alaska and Everts Air Cargo',
#        'Wright Air Service', 'Grant Aviation',
#        'Hageland Aviation Service', 'Atlas Air Inc.',
#        'London Air Services Limited', 'Albinati aviation Limited',
#        'Royal Air Maroc', 'Thomas Cook Airlines Uk Ltd.',
#        'Nolinor Aviation', 'Fly Jamaica Airways Limited',
#        'Philippine Airlines Inc.', 'Compagnia Aerea Italiana',
#        'Britannia Airways Ltd.', 'Air Atlanta Icelandic',
#        'Empire Airlines Inc.', 'Klm Royal Dutch Airlines', 'ABS JETS A.S',
#        'Talofa Airways Limited', 'Martinair Holland N.V.',
#        'Aerotransportes Mas De Crga', 'Aerovias de Intergracian Regional',
#        'LAN Argentina', 'Air China', 'Compania Panamena (Copa)',
#        'Lan Peru Airlines', 'ABSA-Aerolinhas Brasileiras',
#        'Glock Aviation GmbH', 'Gainjet Aviation SA', 'Lan Colombia',
#        'Lan-Chile Airlines', 'Air Charter, Inc d/b/a Air Flamenco',
#        'Aerodynamics Inc. d/b/a SkyValue d/b/a SkyValue Airways',
#        'Compass Airlines', 'JetBlue Airways',
#        'Ultimate JetCharters LLC dba Ultimate Air Shuttle',
#        'Polaris Aviation Solutions, LLC', 'Ward Air',
#        'Air Asia X Berhad dba Airasia X', 'Beijing Capital Airlines',
#        'Hawaiian Airlines Inc.', 'Katmai Air', 'Unijet',
#        'Chartright Air Inc.', 'Air Alsie A/S',
#        'Cebu Air Inc d/b/a Cebu Pacific Air', 'CAT Aviation',
#        'Etihad Airways',
#        'Transportes Aereos Mercantiles Panamericanos S.A',
#        'TAG Aviation (UK) Ltd.', 'Cayman Airways Limited',
#        'Swift Air, LLC d/b/a Eastern Air Lines d/b/a Eastern',
#        'KaiserAir, Inc.', 'Kalinin Aviation LLC d/b/a Alaska Seaplanes',
#        'Spernak Airways Inc.', 'Compagnie Natl Air France',
#        'C.A.L Cargo Airlines', 'ABC Aerolineas SA de CV dba Interjet',
#        'Azul Linhas Aereas Brazileiras S A', 'JetClub AG',
#        'Flying Service N.V.', 'Dassault Falcon Service',
#        'Svenskt Industriflyg AB', 'Cathay Pacific Airways Ltd.',
#        'Icelandair', 'TAG Aviation S.A.', 'Flying Group Lux S.A.',
#        '40-Mile Air', 'Hong Kong Airlines Limited',
#        'Jetstar Airways Pty Limited', 'Antonov Company',
#        'National Aviation Company of India Limited d/b/a Air India',
#        'Norwegian Air International Ltd.', 'Norwegian Air UK Limited',
#        'Norwegian Air Shuttle ASA', 'El Al Israel Airlines Ltd.',
#        'China Eastern Airlines', 'Blue Jet SP Z o o',
#        'Aerounion Aerotransporte de Carga Union SA de CV',
#        'Silk Way West Airlines', 'Edelweiss Air Ag',
#        'Avior Airlines, C.A.', 'Swiss International Airlines',
#        'Titan Airways', 'Iberia Air Lines Of Spain',
#        'Omni Air International LLC', 'Egyptair', 'Air Pacific Ltd.',
#        'Korean Air Lines Co. Ltd.', 'Ethiopian Airlines',
#        'Ryan Air f/k/a Arctic Transportation',
#        'TUI Airlines Nederland B.V.', 'Surinam Airways Limited',
#        'Air Transat', 'Bahamasair Holding Limited', 'Air Europa',
#        'Western Global', 'Kuwait Airways Corp.', 'Cargolux Italia SpA',
#        'China Southern Airlines', 'Eurowings GmbH', 'DCA',
#        'ADVANCED AIR, LLC', 'Air New Zealand', 'Austrian Airlines',
#        'Asiana Airlines Inc.', 'Bradley Air Services Ltd.',
#        'Comlux Malta, Ltd.', 'Comlux Aruba NV', 'British Airways Plc',
#        'Azerbaijan Airlines CJSC', 'Horizon Air', 'Virgin America',
#        'Transportes Aereos De Cabo', 'USA Jet Airlines Inc.',
#        'Air Canada', 'Sky Regional Airlines Inc.',
#        'Transportes Aeromar S.A de C.V',
#        'TEM Enterprises dba  Avelo Airlines', 'Silver Airways',
#        'Rhoades Aviation dba Transair',
#        'Public Charters, Inc. d/b/a North Country Sky d/b/a Regional Sky d/b/a Texas Sky',
#        'Jet Aviation Flight Services, Inc.', 'Air Busan',
#        'Uzbekistan Airways',
#        'Trans Northern Airways d/b/a Air Unlimited Charter Services',
#        'Luxaviation Germany GmbH',
#        'Air Hamburg Luftverkehrsgesellschaft mbH',
#        'Aerolineas Argentinas', 'Aer Lingus Plc', 'Aviateca, S.A.',
#        'Volga-Dnepr Airlines',
#        'Eastern Airlines f/k/a Dynamic Airways, LLC', 'Skyfirst Limited',
#        'Finnair Oy',
#        'J&M Alaska Air Tours, Inc. d/b/a Alaska Air Transit',
#        'Japan Air Lines Co. Ltd.', "Elysair d/b/a L'Avion",
#        'Dreamjet SAS Dba La Compagnie', 'Caribbean Airlines Limited',
#        'Acropolis Aviation Ltd.', 'Lufthansa German Airlines',
#        'Sichuan Airlines Co Ltd.', 'Luxaviation S A', 'Air Sunshine Inc.',
#        'Jeju Air Co Ltd.', 'Sparfell Luftfahrt GmbH', 'Cape Air',
#        'Hillwood Airways, LLC  f/k/a   ATX Air Services, LLC',
#        'Southern Air Inc.', 'United Air Lines Inc.',
#        'Estafeta Carga Aereas',
#        'Venture Travel LLC d/b/a Taquan Air Service',
#        'Prescott Support Company, Inc.', 'DHL Aero Expresso',
#        'Tame Linea Aerea del Ecuador Tme EP', 'Airitaly S.P.A.',
#        'Laudamotion GmbH', 'Jet2.com', 'AeroLogic GmbH',
#        'Flair Airlines Ltd.', 'Kenya Airways PLC',
#        'VRG Linhas Aereas S A', 'Transportes Aeros Meridiona',
#        'Mjet GmbH', 'Multi-Aero, Inc. d/b/a Air Choice One',
#        'Kalitta Charters II', 'Vieques Air Link Inc.',
#        'International Jet Management GmbH', 'Air Company Yakutia',
#        'Longtail Aviation Ltd.', 'Alia-(The) Royal Jordanian',
#        'Privatair', 'Jet Aviation Business Jets AG',
#        'Vuela Aviacion, S.A.', 'Great Lakes Airlines',
#        'Southern Airways Express, dba Mokulele Airlines',
#        'Frontier Flying Service', 'OPENSKIES SAS', 'French bee',
#        'SkyWest Airlines Inc.', 'Piedmont Airlines', 'Bemidji Airlines',
#        'Frontier Airlines Inc.',
#        'Commutair Aka Champlain Enterprises, Inc.',
#        'ExpressJet Airlines LLC', 'United Parcel Service',
#        'PSA Airlines Inc.', 'Air Wisconsin Airlines Corp',
#        'Elite Airways LLC', 'Delux Public Charter LLC',
#        'Amerijet International', nan, 'Spirit Air Lines',
#        'Rectrix Aviation, Inc.', 'New England Airlines Inc.',
#        'Seaborne Virgin Islands, Inc.', 'Key Lime Air Corporation',
#        'Ellis Air Taxi Inc.', 'Reeve Air Alaska, LLC',
#        'Nealco Air Charter Services, Inc.  d/b/a  Watermakers Air',
#        'Friday Harbor Seaplanes', 'Grand Canyon Helicopters',
#        'Makani Kai Air Charters', 'City Wings Inc dba Seaflight'],
#       dtype=object)

# %%
aircraft_type = pd.read_csv('original_data\\L_AIRCRAFT_TYPE.csv')
aircraft_type.rename(columns={'Description':'Plane_Type_Text'},inplace=True)
aircraft_group = pd.read_csv('original_data\\L_AIRCRAFT_GROUP.csv')
aircraft_group.rename(columns={'Description':'Plane_Group_Text'},inplace=True)
aircraft_config = pd.read_csv('original_data\\L_AIRCRAFT_CONFIG.csv')
aircraft_config.rename(columns={'Description':'Plane_Config_Text'},inplace=True)
aircraft_type
# Out:
#      Code                                    Plane_Type_Text
# 0       7                                 Aero Commander 200
# 1       8                                  Aero Macchi AL-60
# 2       9                                       Aeronca 7-AC
# 3      10          Beech Bonanza 35A/C/D/E/G/H/J/K/S/V/  36A
# 4      20                                    Bellanca CH-300
# ..    ...                                                ...
# 423   887                                B787-800 Dreamliner
# 424   888                                   Boeing 737-900ER
# 425   889                                B787-900 Dreamliner
# 426   890                             Antonov 225 (6 Engine)
# 427   999  Used for capturing expenses not attributed to ...
#
# [428 rows x 2 columns]

# %%
df_routes_planes_airports = route_list.merge(aircraft_type, how = 'left', 
left_on = 'AIRCRAFT_TYPE', right_on = 'Code')
df_routes_planes_airports = df_routes_planes_airports.merge(aircraft_group, 
how = 'left', left_on = 'AIRCRAFT_GROUP', right_on = 'Code')
df_routes_planes_airports = df_routes_planes_airports.merge(aircraft_config, 
how = 'left', left_on = 'AIRCRAFT_CONFIG', right_on = 'Code')
df_routes_planes_airports = df_routes_planes_airports.merge(
    origin_airport_list_for_merge, how = 'left', left_on = 'ORIGIN',
    right_on = 'origin_iata_code') 
df_routes_planes_airports = df_routes_planes_airports.merge(
    destination_airport_list_for_merge, how = 'left', left_on = 'DEST',
    right_on = 'destination_iata_code') 
df_routes_planes_airports
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED    PAYLOAD   SEATS  \
# 0                        0.0                   1.0    21502.0    76.0
# 1                        0.0                   3.0    64506.0   228.0
# 2                        0.0                   1.0    21502.0    76.0
# 3                        0.0                   1.0    21502.0    76.0
# 4                        0.0                   1.0    12500.0    50.0
# ...                      ...                   ...        ...     ...
# 482268                1166.0                 583.0  1049400.0  5247.0
# 482269                1188.0                 594.0  1069200.0  5346.0
# 482270                1216.0                 608.0  1094400.0  5472.0
# 482271                1258.0                 629.0  1132200.0  5661.0
# 482272                2170.0                  44.0    74400.0   264.0
#
#         PASSENGERS  FREIGHT  MAIL  DISTANCE  RAMP_TO_RAMP  AIR_TIME  ...  \
# 0              3.0      0.0   0.0     901.0         170.0     140.0  ...
# 1             75.0      0.0   0.0     228.0         219.0     140.0  ...
# 2             64.0      0.0   0.0     851.0         144.0     114.0  ...
# 3             55.0      0.0   0.0     122.0          58.0      31.0  ...
# 4             34.0      0.0   0.0     133.0          49.0      29.0  ...
# ...            ...      ...   ...       ...           ...       ...  ...
# 482268      3646.0      0.0   0.0      91.0       27284.0   21338.0  ...
# 482269      3573.0      0.0   0.0      91.0       27799.0   21740.0  ...
# 482270      3827.0      0.0   0.0      91.0       28454.0   22253.0  ...
# 482271      4056.0      0.0   0.0      91.0       29437.0   23021.0  ...
# 482272         0.0      0.0  44.0      59.0        1860.0       0.0  ...
#
#        Code_y  Plane_Group_Text Code        Plane_Config_Text  \
# 0           6     Jet, 2-Engine    1  Passenger Configuration
# 1           6     Jet, 2-Engine    1  Passenger Configuration
# 2           6     Jet, 2-Engine    1  Passenger Configuration
# 3           6     Jet, 2-Engine    1  Passenger Configuration
# 4           6     Jet, 2-Engine    1  Passenger Configuration
# ...       ...               ...  ...                      ...
# 482268      1  Piston, 2-Engine    1  Passenger Configuration
# 482269      1  Piston, 2-Engine    1  Passenger Configuration
# 482270      1  Piston, 2-Engine    1  Passenger Configuration
# 482271      1  Piston, 2-Engine    1  Passenger Configuration
# 482272      3   Helicopter/Stol    1  Passenger Configuration
#
#        origin_iata_code origin_lat origin_lon  destination_iata_code  \
# 0                   IAD     38.944    -77.456                    FLL
# 1                   IAD     38.944    -77.456                    JFK
# 2                   IAH     29.980    -95.340                    SAV
# 3                   ILM     34.271    -77.903                    RDU
# 4                   IND     39.717    -86.294                    NaN
# ...                 ...        ...        ...                    ...
# 482268              ACK     41.253    -70.060                    BOS
# 482269              BOS     42.364    -71.005                    ACK
# 482270              ACK     41.253    -70.060                    BOS
# 482271              BOS     42.364    -71.005                    ACK
# 482272              NaN        NaN        NaN                    NaN
#
#         destination_lat  destination_lon
# 0                26.072          -80.153
# 1                40.640          -73.779
# 2                32.127          -81.202
# 3                35.877          -78.787
# 4                   NaN              NaN
# ...                 ...              ...
# 482268           42.364          -71.005
# 482269           41.253          -70.060
# 482270           42.364          -71.005
# 482271           41.253          -70.060
# 482272              NaN              NaN
#
# [482273 rows x 63 columns]

# %%
df_routes_planes_airports.to_csv('routes_planes_coordinates.csv')

# %%
df_routes_planes_airports_for_mapping = df_routes_planes_airports.copy()
df_routes_planes_airports_for_mapping.dropna(axis=0,subset=['origin_iata_code',
 'destination_iata_code', 'destination_lat', 'destination_lon'],inplace=True) 
df_routes_planes_airports_for_mapping = df_routes_planes_airports_for_mapping.query(
    "origin_lat != 0 and origin_lon != 0 and destination_lat != 0 \
        and destination_lon != 0")
df_routes_planes_airports_for_mapping
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED    PAYLOAD   SEATS  \
# 0                        0.0                   1.0    21502.0    76.0
# 1                        0.0                   3.0    64506.0   228.0
# 2                        0.0                   1.0    21502.0    76.0
# 3                        0.0                   1.0    21502.0    76.0
# 5                        0.0                   1.0    21502.0    76.0
# ...                      ...                   ...        ...     ...
# 482267                1146.0                 573.0  1031400.0  5157.0
# 482268                1166.0                 583.0  1049400.0  5247.0
# 482269                1188.0                 594.0  1069200.0  5346.0
# 482270                1216.0                 608.0  1094400.0  5472.0
# 482271                1258.0                 629.0  1132200.0  5661.0
#
#         PASSENGERS  FREIGHT  MAIL  DISTANCE  RAMP_TO_RAMP  AIR_TIME  ...  \
# 0              3.0      0.0   0.0     901.0         170.0     140.0  ...
# 1             75.0      0.0   0.0     228.0         219.0     140.0  ...
# 2             64.0      0.0   0.0     851.0         144.0     114.0  ...
# 3             55.0      0.0   0.0     122.0          58.0      31.0  ...
# 5              0.0      0.0   0.0     476.0         157.0     138.0  ...
# ...            ...      ...   ...       ...           ...       ...  ...
# 482267      3693.0      0.0   0.0      91.0       26816.0   20972.0  ...
# 482268      3646.0      0.0   0.0      91.0       27284.0   21338.0  ...
# 482269      3573.0      0.0   0.0      91.0       27799.0   21740.0  ...
# 482270      3827.0      0.0   0.0      91.0       28454.0   22253.0  ...
# 482271      4056.0      0.0   0.0      91.0       29437.0   23021.0  ...
#
#        Code_y  Plane_Group_Text Code        Plane_Config_Text  \
# 0           6     Jet, 2-Engine    1  Passenger Configuration
# 1           6     Jet, 2-Engine    1  Passenger Configuration
# 2           6     Jet, 2-Engine    1  Passenger Configuration
# 3           6     Jet, 2-Engine    1  Passenger Configuration
# 5           6     Jet, 2-Engine    1  Passenger Configuration
# ...       ...               ...  ...                      ...
# 482267      1  Piston, 2-Engine    1  Passenger Configuration
# 482268      1  Piston, 2-Engine    1  Passenger Configuration
# 482269      1  Piston, 2-Engine    1  Passenger Configuration
# 482270      1  Piston, 2-Engine    1  Passenger Configuration
# 482271      1  Piston, 2-Engine    1  Passenger Configuration
#
#        origin_iata_code origin_lat origin_lon  destination_iata_code  \
# 0                   IAD     38.944    -77.456                    FLL
# 1                   IAD     38.944    -77.456                    JFK
# 2                   IAH     29.980    -95.340                    SAV
# 3                   ILM     34.271    -77.903                    RDU
# 5                   IND     39.717    -86.294                    IAD
# ...                 ...        ...        ...                    ...
# 482267              ACK     41.253    -70.060                    BOS
# 482268              ACK     41.253    -70.060                    BOS
# 482269              BOS     42.364    -71.005                    ACK
# 482270              ACK     41.253    -70.060                    BOS
# 482271              BOS     42.364    -71.005                    ACK
#
#         destination_lat  destination_lon
# 0                26.072          -80.153
# 1                40.640          -73.779
# 2                32.127          -81.202
# 3                35.877          -78.787
# 5                38.944          -77.456
# ...                 ...              ...
# 482267           42.364          -71.005
# 482268           42.364          -71.005
# 482269           41.253          -70.060
# 482270           42.364          -71.005
# 482271           41.253          -70.060
#
# [349173 rows x 63 columns]

# %%
df_routes_planes_airports_for_mapping.to_csv(
    'routes_planes_coordinates_for_mapping.csv')

# %% [markdown]
# The following cell, applied to a copy of df_routes_planes_airports_for_mapping, creates a new column showing the origin and destination airports separated by an underscore. These airports are sorted alphabetically, which allows flights from Airport B to Airport A and from Airport A to Airport B to be consolidated together within the route mapping notebook. Using np.where() as opposed to a for loop saved a considerable amount of time.

# %%
df_routes_planes_airports_for_mapping_v2 = \
df_routes_planes_airports_for_mapping.copy()
df_routes_planes_airports_for_mapping_v2.reset_index(drop=True,inplace=True)


df_routes_planes_airports_for_mapping_v2['ORIGIN_DEST'] = \
np.where(df_routes_planes_airports_for_mapping_v2['ORIGIN'] < \
df_routes_planes_airports_for_mapping_v2['DEST'], 
df_routes_planes_airports_for_mapping_v2['ORIGIN'] + '_' + \
df_routes_planes_airports_for_mapping_v2['DEST'], 
df_routes_planes_airports_for_mapping_v2['DEST'] + \
'_' + df_routes_planes_airports_for_mapping_v2['ORIGIN'])

# The following for loop took over 23 minutes to run, 
# whereas the np.where() approach took 0.2 seconds!
# df_routes_planes_airports_for_mapping_v2.reset_index(drop=True,inplace=True)
# df_routes_planes_airports_for_mapping_v2['ORIGIN_DEST'] = ''
# loop_start_time = time.time()
# for i in range(len(df_routes_planes_airports_for_mapping_v2)):
#     if i % 1000 == 0:
#         print("Now on row",i)
#         print("elapsed time (in seconds):", time.time() - loop_start_time)
#     origin_airport = \
#     df_routes_planes_airports_for_mapping_v2.iloc[i, 
#     df_routes_planes_airports_for_mapping_v2.columns.get_loc('ORIGIN')]
#     destination_airport = \
#     df_routes_planes_airports_for_mapping_v2.iloc[i, 
#     df_routes_planes_airports_for_mapping_v2.columns.get_loc('DEST')]
#     if origin_airport < destination_airport:
#         origin_dest = origin_airport+'_'+destination_airport
#     else:
#         origin_dest = destination_airport+'_'+origin_airport
#     df_routes_planes_airports_for_mapping_v2.iloc[i, 
#     df_routes_planes_airports_for_mapping_v2.columns.get_loc('ORIGIN_DEST')] = \
#             origin_dest

# %%
df_routes_planes_airports_for_mapping_v2
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED    PAYLOAD   SEATS  \
# 0                        0.0                   1.0    21502.0    76.0
# 1                        0.0                   3.0    64506.0   228.0
# 2                        0.0                   1.0    21502.0    76.0
# 3                        0.0                   1.0    21502.0    76.0
# 4                        0.0                   1.0    21502.0    76.0
# ...                      ...                   ...        ...     ...
# 349168                1146.0                 573.0  1031400.0  5157.0
# 349169                1166.0                 583.0  1049400.0  5247.0
# 349170                1188.0                 594.0  1069200.0  5346.0
# 349171                1216.0                 608.0  1094400.0  5472.0
# 349172                1258.0                 629.0  1132200.0  5661.0
#
#         PASSENGERS  FREIGHT  MAIL  DISTANCE  RAMP_TO_RAMP  AIR_TIME  ...  \
# 0              3.0      0.0   0.0     901.0         170.0     140.0  ...
# 1             75.0      0.0   0.0     228.0         219.0     140.0  ...
# 2             64.0      0.0   0.0     851.0         144.0     114.0  ...
# 3             55.0      0.0   0.0     122.0          58.0      31.0  ...
# 4              0.0      0.0   0.0     476.0         157.0     138.0  ...
# ...            ...      ...   ...       ...           ...       ...  ...
# 349168      3693.0      0.0   0.0      91.0       26816.0   20972.0  ...
# 349169      3646.0      0.0   0.0      91.0       27284.0   21338.0  ...
# 349170      3573.0      0.0   0.0      91.0       27799.0   21740.0  ...
# 349171      3827.0      0.0   0.0      91.0       28454.0   22253.0  ...
# 349172      4056.0      0.0   0.0      91.0       29437.0   23021.0  ...
#
#         Plane_Group_Text  Code        Plane_Config_Text origin_iata_code  \
# 0          Jet, 2-Engine     1  Passenger Configuration              IAD
# 1          Jet, 2-Engine     1  Passenger Configuration              IAD
# 2          Jet, 2-Engine     1  Passenger Configuration              IAH
# 3          Jet, 2-Engine     1  Passenger Configuration              ILM
# 4          Jet, 2-Engine     1  Passenger Configuration              IND
# ...                  ...   ...                      ...              ...
# 349168  Piston, 2-Engine     1  Passenger Configuration              ACK
# 349169  Piston, 2-Engine     1  Passenger Configuration              ACK
# 349170  Piston, 2-Engine     1  Passenger Configuration              BOS
# 349171  Piston, 2-Engine     1  Passenger Configuration              ACK
# 349172  Piston, 2-Engine     1  Passenger Configuration              BOS
#
#        origin_lat origin_lon destination_iata_code  destination_lat  \
# 0          38.944    -77.456                   FLL           26.072
# 1          38.944    -77.456                   JFK           40.640
# 2          29.980    -95.340                   SAV           32.127
# 3          34.271    -77.903                   RDU           35.877
# 4          39.717    -86.294                   IAD           38.944
# ...           ...        ...                   ...              ...
# 349168     41.253    -70.060                   BOS           42.364
# 349169     41.253    -70.060                   BOS           42.364
# 349170     42.364    -71.005                   ACK           41.253
# 349171     41.253    -70.060                   BOS           42.364
# 349172     42.364    -71.005                   ACK           41.253
#
#         destination_lon  ORIGIN_DEST
# 0               -80.153      FLL_IAD
# 1               -73.779      IAD_JFK
# 2               -81.202      IAH_SAV
# 3               -78.787      ILM_RDU
# 4               -77.456      IAD_IND
# ...                 ...          ...
# 349168          -71.005      ACK_BOS
# 349169          -71.005      ACK_BOS
# 349170          -70.060      ACK_BOS
# 349171          -71.005      ACK_BOS
# 349172          -70.060      ACK_BOS
#
# [349173 rows x 64 columns]

# %%
df_routes_planes_airports_for_mapping_v2.to_csv(
    'routes_planes_coordinates_for_mapping_v2.csv')
